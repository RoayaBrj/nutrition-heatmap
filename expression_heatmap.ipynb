# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\notebook\counts.tsv", 
                 sep="\t", index_col=0)

df_log2 = np.log2(df + 1)

plt.figure(figsize=(7,4))
plt.imshow(df_log2, aspect="auto")
plt.colorbar(label="log2(TPM+1)")
plt.xticks(range(len(df.columns)), df.columns, rotation=45, ha="right")
plt.yticks(range(len(df.index)), df.index)
plt.title("Nutrition genes – GTEx median TPMs")
plt.tight_layout()
plt.show()
plt.savefig("heatmap.png", dpi=300, bbox_inches="tight")

# %%
df.describe().T
# Out:
#                 count     mean        std  min    25%    50%    75%    max
# Pancreas          8.0  34.2125  87.334160  0.3  0.475   1.25   7.50  250.0
# Liver             8.0  13.1375  27.840615  0.2  0.475   1.00   6.50   80.0
# SkeletalMuscle    8.0  35.8000  69.460102  0.1  0.175   3.00  30.00  200.0
# AdiposeSubQ       8.0  27.7125  35.269146  0.3  0.850  17.50  33.75  100.0
# AdiposeVisc       8.0  22.7125  27.056525  0.3  0.850  17.50  28.75   80.0
# WholeBlood        8.0   2.2125   3.547811  0.0  0.100   0.75   2.00   10.0
